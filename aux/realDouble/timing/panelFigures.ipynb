# %%
# Package imports
import numpy as np

# My own files
from aux import *
from parse import *
from perf import *

# %%
(mVec, nVec, \
           qr_opt_time, qr_ref_time, qr_new_time, \
           lq_opt_time, lq_ref_time, lq_new_time) = parsePanelFile("perf_files/rect_orgkr_12_09_25.txt")

# %%
xVec = nVec
tmp = np.array([qr_opt_time, qr_ref_time, qr_new_time])
yVecs = orgkrPerf(tmp,mVec,nVec)
labelVecs = np.array(["AOCL", "Reference", "ORGKR"])
xLabel = "Number of reflectors (n)"
yLabel = r'Performance: $\frac{4mn^2}{10^9\text{time}}$'
title = r'Performance for panel factorization (n=k) with $m=10000, n$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/rect_orgkr_10000.png")

# %%
xVec = nVec
tmp = np.array([lq_opt_time, lq_ref_time, lq_new_time])
yVecs = orgqrPerf(tmp,mVec,nVec,nVec)
labelVecs = np.array(["AOCL", "Reference", "ORGLK"])
xLabel = "Number of reflectors (k)"
yLabel = r'Performance: $\frac{4mn^2}{10^9\text{time}}$'
title = r'Performance for panel factorization with $m=10000, n$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/rect_orglk_10000.png")

# %%
(mVec, nVec, \
           qr_opt_time, qr_ref_time, qr_new_time, \
           lq_opt_time, lq_ref_time, lq_new_time) = parsePanelFile("perf_files/rect_orgkr_small_12_09_25.txt")

# %%
xVec = nVec
tmp = np.array([qr_opt_time, qr_ref_time, qr_new_time])
yVecs = orgkrPerf(tmp,mVec,nVec)
labelVecs = np.array(["AOCL", "Reference", "ORGKR"])
xLabel = "Number of reflectors (k)"
yLabel = r'Performance: $\frac{4mn^2}{10^9\text{time}}$'
title = r'Performance for panel factorization with $m=10000, n$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/rect_orgkr_small_10000.png")

# %%
xVec = nVec
tmp = np.array([lq_opt_time, lq_ref_time, lq_new_time])
yVecs = orgkrPerf(tmp,mVec,nVec)
labelVecs = np.array(["AOCL", "Reference", "ORGLK"])
xLabel = "Number of reflectors (k)"
yLabel = r'Performance: $\frac{4mn^2}{10^9\text{time}}$'
title = r'Performance for panel factorization with $m=10000, n$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/rect_orglk_small_10000.png")
