# %%
# Package imports
import numpy as np

# My own files
from aux import *
from parse import *
from perf import *

# %%
(mVec, nVec, kVec, nbVec, \
            qr_opt_time, qr_ref_time, qr_lvl2_time, qr_rec_time, qr_ut_inv_time, qr_ut_solve_time, \
            qr_opt_perf, qr_ref_perf, qr_lvl2_perf, qr_rec_perf, qr_ut_inv_perf, qr_ut_solve_perf, \
            lq_opt_time, lq_ref_time, lq_lvl2_time, lq_rec_time, lq_ut_inv_time, lq_ut_solve_time, \
            lq_opt_perf, lq_ref_perf, lq_lvl2_perf, lq_rec_perf, lq_ut_inv_perf, lq_ut_solve_perf) = parseOrgFile("perf_files/rect_orgqr_12_09_25.txt")

# %%
xVec = kVec[0:-2]
yVecs = np.array([qr_opt_perf[0:-2], qr_ref_perf[0:-2], qr_lvl2_perf[0:-2], qr_rec_perf[0:-2], qr_ut_inv_perf[0:-2], qr_ut_solve_perf[0:-2]])
labelVecs = np.array(["AOCL", "Reference", "LVL2 BLAS", "RECURSIVE", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = "Performance: GFlop/s"
title = "GFlop/s for dorgqr with m = 10000, n=k, nb=64"
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/qr_org_10000_k.png")

# %%
xVec = kVec
yVecs = np.array([lq_opt_perf, lq_ref_perf, lq_lvl2_perf, lq_rec_perf, lq_ut_inv_perf, lq_ut_solve_perf])
labelVecs = np.array(["AOCL", "Reference", "LVL2 BLAS", "RECURSIVE", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = "Performance: GFlop/s"
title = "GFlop/s for dorglq with n = 10000, m=k, nb=64"
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/lq_org_10000_k.png")

# %%
(mVec, nVec, kVec, nbVec, \
            qr_opt_time, qr_ref_time, qr_lvl2_time, qr_rec_time, qr_ut_inv_time, qr_ut_solve_time, \
            qr_opt_perf, qr_ref_perf, qr_lvl2_perf, qr_rec_perf, qr_ut_inv_perf, qr_ut_solve_perf, \
            lq_opt_time, lq_ref_time, lq_lvl2_time, lq_rec_time, lq_ut_inv_time, lq_ut_solve_time, \
            lq_opt_perf, lq_ref_perf, lq_lvl2_perf, lq_rec_perf, lq_ut_inv_perf, lq_ut_solve_perf) = parseOrgFile("perf_files/rect_orgqr_nb_12_09_25.txt")

# %%
xVec = nbVec
yVecs = np.array([qr_opt_perf, qr_ref_perf, qr_lvl2_perf, qr_rec_perf, qr_ut_inv_perf, qr_ut_solve_perf])
labelVecs = np.array(["AOCL", "Reference", "LVL2 BLAS", "RECURSIVE", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = "Performance: GFlop/s"
title = r'GFlop/s for dorgqr with $m=10000, n=k=1000$, nb varies'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/qr_org_10000_nb.png")

# %%
xVec = nbVec
yVecs = np.array([lq_opt_perf, lq_ref_perf, lq_lvl2_perf, lq_rec_perf, lq_ut_inv_perf, lq_ut_solve_perf])
labelVecs = np.array(["AOCL", "Reference", "LVL2 BLAS", "RECURSIVE", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = "Performance: GFlop/s"
title = r'GFlop/s for dorglq with $m=10000, n=k=1000$, nb varies'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/lq_org_10000_nb.png")

# %%
(mVec, nVec, kVec, nbVec, \
            qr_opt_time, qr_ref_time, qr_lvl2_time, qr_rec_time, qr_ut_inv_time, qr_ut_solve_time, \
            qr_opt_perf, qr_ref_perf, qr_lvl2_perf, qr_rec_perf, qr_ut_inv_perf, qr_ut_solve_perf, \
            lq_opt_time, lq_ref_time, lq_lvl2_time, lq_rec_time, lq_ut_inv_time, lq_ut_solve_time, \
            lq_opt_perf, lq_ref_perf, lq_lvl2_perf, lq_rec_perf, lq_ut_inv_perf, lq_ut_solve_perf) = parseOrgFile("perf_files/square_orgqr_nb_k_12_10_25.txt")

# %%
xVec = kVec
tmp = np.array([qr_opt_time, qr_ref_time, qr_lvl2_time, qr_rec_time, qr_ut_inv_time, qr_ut_solve_time])
yVecs = orgqrPerf(tmp,mVec,nVec,kVec)
labelVecs = np.array(["ORG2R", "No LARFB0C2", "LVL2", "Recursive", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = r'Performance: Gflop/s for ORGQR'
title = r'GFlop/s for dorgqr with $m=n=10000, k=nb$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/square_orgqr_nb_k_10000.png")

# %%
# add 2r and l2
xVec = kVec
tmp = np.array([lq_opt_time, lq_ref_time, lq_lvl2_time, lq_rec_time, lq_ut_inv_time, lq_ut_solve_time])
yVecs = orgqrPerf(tmp,mVec,nVec,kVec)
labelVecs = np.array(["ORGL2", "No LARFB0C2", "LVL2", "Recursive", "UT_INV", "UT_SOLVE"])
xLabel = "Number of reflectors (k)"
yLabel = r'Performance: Gflop/s for ORGLQ'
title = r'GFlop/s for dorglq with $m=n=10000, k=nb$ varying'
createFigure(xVec, yVecs, labelVecs, title, xLabel, yLabel, filename="figures/square_orglq_nb_k_10000.png")
